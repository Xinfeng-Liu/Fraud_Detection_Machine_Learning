# %%
import configparser

# %%
config = configparser.RawConfigParser()

# %%
file = open('environment_config.ini', 'w')

# %%
config.add_section('Library1')
config.set('Library1', 'Name', 'pandas')
config.set('Library1', 'Version', '1.3.2')

config.add_section('Library2')
config.set('Library2', 'Name', 'numpy')
config.set('Library2', 'Version', '1.20.3')

config.add_section('Library3')
config.set('Library3', 'Name', 'sweetviz')
config.set('Library3', 'Version', '2.1.3')

config.add_section('Library4')
config.set('Library4', 'Name', 'scikit-learn')
config.set('Library4', 'Version', '0.24.2')

config.add_section('Library5')
config.set('Library5', 'Name', 'category_encoders')
config.set('Library5', 'Version', '2.2.2')

config.add_section('Library6')
config.set('Library6', 'Name', 'xgboost')
config.set('Library6', 'Version', 'xgboost')

# %%
config.write(file)

# %%
file.close()
